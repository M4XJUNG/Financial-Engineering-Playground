# %% [markdown]
# <a href="https://colab.research.google.com/github/M4XJUNG/Financial-Engineering-Playground/blob/main/doit-pandas/notebook/03_done.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 직접 해보세요!
# ## 시리즈와 데이터프레임 직접 만들기(51쪽)
# ### 1. 시리즈 만들기

# %%
import pandas as pd
s = pd.Series(['banana', 42])
print(s)
# Out:
# 0    banana
# 1        42
# dtype: object

# %%
s = pd.Series(['Wes McKinney', 'Creator of Pandas'])
print(s)
# Out:
# 0         Wes McKinney
# 1    Creator of Pandas
# dtype: object

# %%
s = pd.Series(['Wes McKinney', 'Creator of Pandas'], index=['Person', 'Who'])
print(s)
# Out:
# Person         Wes McKinney
# Who       Creator of Pandas
# dtype: object

# %% [markdown]
# ### 3. 데이터프레임 만들기

# %%
scientists = pd.DataFrame({
    'Name': ['Rosaline Franklin', 'William Gosset'],
    'Occupation': ['Chemist', 'Statistician'],
    'Born': ['1920-07-25', '1876-06-13'],
    'Died': ['1958-04-16', '1937-10-16'],
    'Age': [37, 61]})
print(scientists)
# Out:
#                 Name    Occupation        Born        Died  Age
# 0  Rosaline Franklin       Chemist  1920-07-25  1958-04-16   37
# 1     William Gosset  Statistician  1876-06-13  1937-10-16   61

# %%
scientists = pd.DataFrame(
    data={'Occupation': ['Chemist', 'Statistician'],
          'Born': ['1920-07-25', '1876-06-13'],
          'Died': ['1958-04-16', '1937-10-16'],
          'Age': [37, 61]},
    index=['Rosaline Franklin', 'William Gosset'],
    columns=['Occupation', 'Born', 'Age', 'Died'])
print(scientists)
# Out:
#                      Occupation        Born  Age        Died
# Rosaline Franklin       Chemist  1920-07-25   37  1958-04-16
# William Gosset     Statistician  1876-06-13   61  1937-10-16

# %%
from collections import OrderedDict

scientists = pd.DataFrame(OrderedDict([
    ('Name', ['Rosaline Franklin', 'William Gosset']),
    ('Occupation', ['Chemist', 'Statistician']),
    ('Born', ['1920-07-25', '1876-06-13']),
    ('Died', ['1958-04-16', '1937-10-16']),
    ('Age', [37, 61])
])
)
print(scientists)
# Out:
#                 Name    Occupation        Born        Died  Age
# 0  Rosaline Franklin       Chemist  1920-07-25  1958-04-16   37
# 1     William Gosset  Statistician  1876-06-13  1937-10-16   61

# %% [markdown]
# # 직접 해보세요!
# ## 데이터프레임에서 시리즈 선택하기(54쪽)

# %%
scientists = pd.DataFrame(
    data={'Occupation': ['Chemist', 'Statistician'],
          'Born': ['1920-07-25', '1876-06-13'],
          'Died': ['1958-04-16', '1937-10-16'],
          'Age': [37, 61]},
    index=['Rosaline Franklin', 'William Gosset'],
    columns=['Occupation', 'Born', 'Died', 'Age'])

# %%
first_row = scientists.loc['William Gosset']
print(type(first_row))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(first_row)
# Out:
# Occupation    Statistician
# Born            1876-06-13
# Died            1937-10-16
# Age                     61
# Name: William Gosset, dtype: object

# %% [markdown]
# # 직접 해보세요!
# ## index, values 속성과 keys 메서드 사용하기(55쪽)

# %% [markdown]
# ### 1. index 속성 사용하기

# %%
print(first_row.index)
# Out:
# Index(['Occupation', 'Born', 'Died', 'Age'], dtype='object')

# %% [markdown]
# ### 2. values 속성 사용하기

# %%
print(first_row.values)
# Out:
# ['Statistician' '1876-06-13' '1937-10-16' np.int64(61)]

# %% [markdown]
# ### 3. keys 메서드 사용하기

# %%
print(first_row.keys())
# Out:
# Index(['Occupation', 'Born', 'Died', 'Age'], dtype='object')

# %% [markdown]
# ### 4. index 속성 응용하기

# %%
print(first_row.index[0])
# Out:
# Occupation

# %% [markdown]
# ### 5. keys 메서드와 index 속성 응용하기

# %%
print(first_row.keys()[0])
# Out:
# Occupation

# %% [markdown]
# # 직접 해보세요!
# ## 시리즈의 mean, min, max, std 메서드 사용하기(56쪽)

# %%
ages = scientists['Age']
print(ages)
# Out:
# Rosaline Franklin    37
# William Gosset       61
# Name: Age, dtype: int64

# %%
print(ages.mean())
# Out:
# 49.0

# %%
print(ages.min())
# Out:
# 37

# %%
print(ages.max())
# Out:
# 61

# %%
print(ages.std())
# Out:
# 16.97056274847714

# %% [markdown]
# # 직접 해보세요!
# ## 시리즈와 불린 추출 사용하기(59쪽)

# %%
# raw.githubusercontent.com 변경 , /blob 삭제
scientists = pd.read_csv('https://raw.githubusercontent.com/M4XJUNG/Financial-Engineering-Playground/main/doit-pandas/data/scientists.csv')

# %%
ages = scientists['Age']

print(ages.max())
# Out:
# 90

# %%
print(ages.mean())
# Out:
# 59.125

# %%
print(ages[ages > ages.mean()])
# Out:
# 1    61
# 2    90
# 3    66
# 7    77
# Name: Age, dtype: int64

# %%
print(ages > ages.mean())
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4    False
# 5    False
# 6    False
# 7     True
# Name: Age, dtype: bool

# %%
print(type(ages > ages.mean()))
# Out:
# <class 'pandas.core.series.Series'>

# %%
manual_bool_values = [True, True, False, False, True, True, False, True]
print(ages[manual_bool_values])
# Out:
# 0    37
# 1    61
# 4    56
# 5    45
# 7    77
# Name: Age, dtype: int64

# %% [markdown]
# # 직접 해보세요!
# ## 벡터와 스칼라로 브로드캐스팅 수행하기(61쪽)

# %%
print(ages + ages)
# Out:
# 0     74
# 1    122
# 2    180
# 3    132
# 4    112
# 5     90
# 6     82
# 7    154
# Name: Age, dtype: int64

# %%
print(ages * ages)
# Out:
# 0    1369
# 1    3721
# 2    8100
# 3    4356
# 4    3136
# 5    2025
# 6    1681
# 7    5929
# Name: Age, dtype: int64

# %%
print(ages + 100)
# Out:
# 0    137
# 1    161
# 2    190
# 3    166
# 4    156
# 5    145
# 6    141
# 7    177
# Name: Age, dtype: int64

# %%
print(ages * 2)
# Out:
# 0     74
# 1    122
# 2    180
# 3    132
# 4    112
# 5     90
# 6     82
# 7    154
# Name: Age, dtype: int64

# %%
print(pd.Series([1, 100]))
# Out:
# 0      1
# 1    100
# dtype: int64

# %%
print(ages + pd.Series([1, 100]))
# Out:
# 0     38.0
# 1    161.0
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# 6      NaN
# 7      NaN
# dtype: float64

# %%
rev_ages = ages.sort_index(ascending=False)
print(rev_ages)
# Out:
# 7    77
# 6    41
# 5    45
# 4    56
# 3    66
# 2    90
# 1    61
# 0    37
# Name: Age, dtype: int64

# %%
print(ages * 2)
# Out:
# 0     74
# 1    122
# 2    180
# 3    132
# 4    112
# 5     90
# 6     82
# 7    154
# Name: Age, dtype: int64

# %%
print(ages + rev_ages)
# Out:
# 0     74
# 1    122
# 2    180
# 3    132
# 4    112
# 5     90
# 6     82
# 7    154
# Name: Age, dtype: int64

# %% [markdown]
# # 직접 해보세요!
# ## 불린 추출과 브로드캐스팅(65쪽)

# %%
print(scientists[scientists['Age'] > scientists['Age'].mean()])
# Out:
#                    Name        Born        Died  Age     Occupation
# 1        William Gosset  1876-06-13  1937-10-16   61   Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90          Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66        Chemist
# 7          Johann Gauss  1777-04-30  1855-02-23   77  Mathematician

# %%
print(scientists.loc[[True, True, False, True]])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-1703941633.py in <cell line: 0>()
# ----> 1 print(scientists.loc[[True, True, False, True]])
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1189             maybe_callable = com.apply_if_callable(key, self.obj)
#    1190             maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191             return self._getitem_axis(maybe_callable, axis=axis)
#    1192
#    1193     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1411             return self._get_slice_axis(key, axis=axis)
#    1412         elif com.is_bool_indexer(key):
# -> 1413             return self._getbool_axis(key, axis=axis)
# ...

# %%
print(scientists * 2)
# Out:
#                                        Name                  Born  \
# 0        Rosaline FranklinRosaline Franklin  1920-07-251920-07-25
# 1              William GossetWilliam Gosset  1876-06-131876-06-13
# 2  Florence NightingaleFlorence Nightingale  1820-05-121820-05-12
# 3                    Marie CurieMarie Curie  1867-11-071867-11-07
# 4                Rachel CarsonRachel Carson  1907-05-271907-05-27
# 5                        John SnowJohn Snow  1813-03-151813-03-15
# 6                    Alan TuringAlan Turing  1912-06-231912-06-23
# 7                  Johann GaussJohann Gauss  1777-04-301777-04-30
#
#                    Died  Age                            Occupation
# 0  1958-04-161958-04-16   74                        ChemistChemist
# 1  1937-10-161937-10-16  122              StatisticianStatistician
# 2  1910-08-131910-08-13  180                            NurseNurse
# 3  1934-07-041934-07-04  132                        ChemistChemist
# ...

# %% [markdown]
# # 직접 해보세요!
# ## 시리즈와 데이터프레임의 데이터 처리하기(67쪽)

# %%
print(scientists['Born'].dtype)
print(scientists['Died'].dtype)
# Out:
# object
# object

# %%
born_datetime = pd.to_datetime(scientists['Born'], format='%Y-%m-%d')
print(born_datetime)
# Out:
# 0   1920-07-25
# 1   1876-06-13
# 2   1820-05-12
# 3   1867-11-07
# 4   1907-05-27
# 5   1813-03-15
# 6   1912-06-23
# 7   1777-04-30
# Name: Born, dtype: datetime64[ns]

# %%
died_datetime = pd.to_datetime(scientists['Died'], format='%Y-%m-%d')
print(died_datetime)
# Out:
# 0   1958-04-16
# 1   1937-10-16
# 2   1910-08-13
# 3   1934-07-04
# 4   1964-04-14
# 5   1858-06-16
# 6   1954-06-07
# 7   1855-02-23
# Name: Died, dtype: datetime64[ns]

# %%
scientists['born_dt'], scientists['died_dt'] = (born_datetime, died_datetime)
print(scientists.head())
# Out:
#                    Name        Born        Died  Age    Occupation    born_dt  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37       Chemist 1920-07-25
# 1        William Gosset  1876-06-13  1937-10-16   61  Statistician 1876-06-13
# 2  Florence Nightingale  1820-05-12  1910-08-13   90         Nurse 1820-05-12
# 3           Marie Curie  1867-11-07  1934-07-04   66       Chemist 1867-11-07
# 4         Rachel Carson  1907-05-27  1964-04-14   56     Biologist 1907-05-27
#
#      died_dt
# 0 1958-04-16
# 1 1937-10-16
# 2 1910-08-13
# 3 1934-07-04
# 4 1964-04-14

# %%
print(scientists.shape)
# Out:
# (8, 7)

# %%
scientists['age_days_dt'] = (scientists['died_dt'] - \
                             scientists['born_dt'])
print(scientists)
# Out:
#                    Name        Born        Died  Age          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician
#
#      born_dt    died_dt age_days_dt
# 0 1920-07-25 1958-04-16  13779 days
# 1 1876-06-13 1937-10-16  22404 days
# 2 1820-05-12 1910-08-13  32964 days
# 3 1867-11-07 1934-07-04  24345 days
# 4 1907-05-27 1964-04-14  20777 days
# 5 1813-03-15 1858-06-16  16529 days
# 6 1912-06-23 1954-06-07  15324 days
# ...

# %% [markdown]
# ### 5. 시리즈, 데이터프레임의 데이터 섞기

# %%
print(scientists['Age'])
# Out:
# 0    37
# 1    61
# 2    90
# 3    66
# 4    56
# 5    45
# 6    41
# 7    77
# Name: Age, dtype: int64

# %%
import random

random.seed(42)
random.shuffle(scientists['Age'])
print(scientists['Age'])
# Out:
# 0    66
# 1    56
# 2    41
# 3    77
# 4    90
# 5    45
# 6    37
# 7    61
# Name: Age, dtype: int64
# /usr/lib/python3.12/random.py:357: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[i], x[j] = x[j], x[i]
# /usr/lib/python3.12/random.py:357: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[i], x[j] = x[j], x[i]
# /usr/lib/python3.12/random.py:357: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %% [markdown]
# ### 7. 데이터프레임의 열 삭제하기

# %%
print(scientists.columns)
# Out:
# Index(['Name', 'Born', 'Died', 'Age', 'Occupation', 'born_dt', 'died_dt',
#        'age_days_dt'],
#       dtype='object')

# %%
scientists_dropped = scientists.drop(['Age'], axis=1)

print(scientists_dropped.columns)
# Out:
# Index(['Name', 'Born', 'Died', 'Occupation', 'born_dt', 'died_dt',
#        'age_days_dt'],
#       dtype='object')

# %% [markdown]
# # 직접 해보세요!
# ## 데이터를 피클, CSV, TSV 파일로 저장하고 불러오기(72쪽)

# %% [markdown]
# ### 1. 피클로 저장하기

# %%
names = scientists['Name']

# %%
# raw.githubusercontent.com 변경 , /blob 삭제
names.to_pickle('https://raw.githubusercontent.com/M4XJUNG/Financial-Engineering-Playground/main/doit-pandas/output/scientists_names_series.pickle')

# %%
# raw.githubusercontent.com 변경 , /blob 삭제
scientists.to_pickle('https://raw.githubusercontent.com/M4XJUNG/Financial-Engineering-Playground/main/doit-pandas/output/scientists_df.pickle')

# %%
# raw.githubusercontent.com 변경 , /blob 삭제
scientist_names_from_pickle = pd.read_pickle('https://raw.githubusercontent.com/M4XJUNG/Financial-Engineering-Playground/main/doit-pandas/output/scientists_names_series.pickle')
print(scientist_names_from_pickle)
# Out:
# 0       Rosaline Franklin
# 1          William Gosset
# 2    Florence Nightingale
# 3             Marie Curie
# 4           Rachel Carson
# 5               John Snow
# 6             Alan Turing
# 7            Johann Gauss
# Name: Name, dtype: object

# %%
# raw.githubusercontent.com 변경 , /blob 삭제
scientists_from_pickle = pd.read_pickle('https://raw.githubusercontent.com/M4XJUNG/Financial-Engineering-Playground/main/doit-pandas/output/scientists_df.pickle')
print(scientists_from_pickle)
# Out:
#                    Name        Born        Died  Age          Occupation
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician

# %% [markdown]
# ### 4. CSV 파일과 TSV 파일로 저장하기

# %%
# raw.githubusercontent.com 변경 , /blob 삭제
names.to_csv('https://raw.githubusercontent.com/M4XJUNG/Financial-Engineering-Playground/main/doit-pandas/output/scientist_names_series.csv')

# %%
# raw.githubusercontent.com 변경 , /blob 삭제
scientists.to_csv('https://raw.githubusercontent.com/M4XJUNG/Financial-Engineering-Playground/main/doit-pandas/output/scientists_df.tsv', sep='\t')

# %%
# raw.githubusercontent.com 변경 , /blob 삭제
scientists.to_csv('https://raw.githubusercontent.com/M4XJUNG/Financial-Engineering-Playground/main/doit-pandas/output/scientists_df_no_index.csv', index=False)

# %%
# raw.githubusercontent.com 변경 , /blob 삭제
names_df = names.to_frame()

# import xlwt
# names_df.to_excel('https://raw.githubusercontent.com/M4XJUNG/Financial-Engineering-Playground/main/doit-pandas/output/scientists_names_series_df.xls')

import openpyxl
names_df.to_excel('https://raw.githubusercontent.com/M4XJUNG/Financial-Engineering-Playground/main/doit-pandas/output/scientists_names_series_df.xlsx')
